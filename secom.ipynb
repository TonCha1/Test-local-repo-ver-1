# %% [markdown]
# <a href="https://colab.research.google.com/github/TonCha1/Test-local-repo-ver-1/blob/main/secom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url_of_label = 'https://raw.githubusercontent.com/TonCha1/Test-local-repo-ver-1/main/secom_labels.data'
url_of_data = 'https://raw.githubusercontent.com/TonCha1/Test-local-repo-ver-1/main/secom.data'
label = pd.read_csv(url_of_label, sep=' ')
data = pd.read_csv(url_of_data, sep=' ')
print(label.head(3),data.head(3))
print(label.shape,data.shape)
# Out:
#    -1  19/07/2008 11:55:00
# 0  -1  19/07/2008 12:32:00
# 1   1  19/07/2008 13:17:00
# 2  -1  19/07/2008 14:43:00    3030.93     2564  2187.7333  1411.1265  1.3602    100   97.6133  0.1242  \
# 0  3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0  102.3433  0.1247
# 1  2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0   95.4878  0.1241
# 2  2988.72  2479.90  2199.0333   909.7926  1.3204  100.0  104.2367  0.1217
#
#    1.5005  0.0162  ...  NaN.38    NaN.39  0.5005  0.0118  0.0035   2.363  \
# 0  1.4966 -0.0005  ...  0.0060  208.2045  0.5019  0.0223  0.0055  4.4447
# 1  1.4436  0.0041  ...  0.0148   82.8602  0.4958  0.0157  0.0039  3.1745
# 2  1.4882 -0.0124  ...  0.0044   73.8432  0.4990  0.0103  0.0025  2.0544
#
#    NaN.40  NaN.41  NaN.42    NaN.43
# 0  0.0096  0.0201  0.0060  208.2045
# 1  0.0584  0.0484  0.0148   82.8602
# 2  0.0202  0.0149  0.0044   73.8432
#
# [3 rows x 590 columns]
# (1566, 2) (1566, 590)

# %%
secom = pd.concat([label, data], ignore_index=True, axis=1)
secom.shape
secom.head(3)
# Out:
#    0                    1        2        3          4          5       6    \
# 0   -1  19/07/2008 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294
# 1    1  19/07/2008 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102
# 2   -1  19/07/2008 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204
#
#      7         8       9    ...     582       583     584     585     586  \
# 0  100.0  102.3433  0.1247  ...  0.0060  208.2045  0.5019  0.0223  0.0055
# 1  100.0   95.4878  0.1241  ...  0.0148   82.8602  0.4958  0.0157  0.0039
# 2  100.0  104.2367  0.1217  ...  0.0044   73.8432  0.4990  0.0103  0.0025
#
#       587     588     589     590       591
# 0  4.4447  0.0096  0.0201  0.0060  208.2045
# 1  3.1745  0.0584  0.0484  0.0148   82.8602
# 2  2.0544  0.0202  0.0149  0.0044   73.8432
#
# [3 rows x 592 columns]

# %%
print("Time = 22:15, Date = 17th April 2024")
# Out:
# Time = 22:15, Date = 17th April 2024

# %%
print("Time = 22:17, Date = 17th April 2024")
#and will also change the name of this .ipynb file from Untitled0.ipynb to secom.ipynb
# Out:
# Time = 22:17, Date = 17th April 2024

# %%
print("Time = 22:20, Date = 17th April 2024")
# Out:
# Time = 22:20, Date = 17th April 2024
